# %%
# Librerías necesarias
import pandas as pd
import requests
from io import BytesIO

# %%
# Obtención datos 3CV con url

url = "https://www.subtrans.gob.cl/wp-content/uploads/2025/12/20_Listado_Vehiculos_Livianos_y_Medianos_Homologados_03_dic_2025.xls"

response = requests.get(url,verify=False)
excel_bytes = BytesIO(response.content)
data_df = pd.read_excel(excel_bytes)
# Out:
# /home/ariel/Escritorio/Proyectos Profesionales/1. Presentacion/Proyectos Portafolios/1. Proyecto 1 ETL Dashboard/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.subtrans.gob.cl'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2                    Unnamed: 3  \
# 0            NaN        NaN        NaN                           NaN
# 1            NaN        NaN        NaN                           NaN
# 2            NaN        NaN      Marca                        Modelo
# 3            NaN        NaN        NaN                           NaN
# 4            NaN        NaN        NaN                           NaN
# ...          ...        ...        ...                           ...
# 7569         NaN       7585  LEAPMOTOR            LPM B10 BEV - Life
# 7570         NaN        NaN  LEAPMOTOR          LPM B10 BEV - Design
# 7571         NaN       7587        KYC         Gran Mamut X5 Plus CS
# 7572         NaN        NaN        KYC         Gran Mamut X5 Plus DC
# 7573         NaN        NaN        KYC  Gran Mamut X5 Plus Cargo Box
#
#        Unnamed: 4   Unnamed: 5          Unnamed: 6         Unnamed: 7  \
# ...

# %%
# Transformación a dataframe
data_df = pd.json_normalize(data["value"])
print(data_df.head())

print(data_df.keys())
# Out:
#   OBS_VALUE TIME_FORMAT  UNIT_MULT COMMENT_OBS OBS_STATUS OBS_CONF AGG_METHOD  \
# 0    655357         602          0        None          A       PU       None
# 1    563106         602          0        None          A       PU       None
# 2   3391125         602          0        None          A       PU       None
# 3  21633587         602          0        None          A       PU       None
# 4     36030         602          0        None          A       PU       None
#
#   DECIMALS COMMENT_TS DATA_SOURCE  ...  SEX AGE URBANISATION COMP_BREAKDOWN_1  \
# 0     None       None        None  ...   _T  _T           _T               _Z
# 1     None       None        None  ...   _T  _T           _T               _Z
# 2     None       None        None  ...   _T  _T           _T               _Z
# 3     None       None        None  ...   _T  _T           _T               _Z
# 4     None       None        None  ...   _T  _T           _T               _Z
#
# ...
